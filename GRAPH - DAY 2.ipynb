# %%
import cufflinks as cf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# consider only the numerical columns
df.plot()
# x-axis => rowindex
# y-axis = column values
# Out:
# <AxesSubplot:>

# %%
# df.describe()

# %%
# with alpha we can able to control the color
# stacked
df.plot(kind='area',alpha=0.9,stacked=False)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length',y='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c="sepal_width")
# to define a color we can use 'C' parameter
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 's' means size (it will represent the dots)
# df.plot.scatter(x='sepal_length',y='petal_length',c="sepal_width",s=100)
df.plot.scatter(x='sepal_length',y='petal_length',c="sepal_width",s=df['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# in the case of hexbin we need to use gridesize for passing size of points
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=10,cmap="viridis")
# cmap is used to change the color
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# mplot3d import from mpl_toolkits
from mpl_toolkits import mplot3d

# %%
# for 3d graph we need three axis like X,Y and Z
# linspace(start,end,size)
x=np.linspace(-1,6,30)
y=np.linspace(-1,6,30)
z=x+y

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
# def sin_fun(x,y):
#     return np.sin(np.sqrt(x**2+y**2))

# %%
z = x+y

# %%
# plotting 3D graph
# creating axes using matplot lib
ax=plt.axes(projection='3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ax=plt.axes(projection='3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_length'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_length')
# Out:
# Text(0.5, 0, 'petal_length')

# %%
# figsize is used to set graph height and width
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot.bar(figsize=(20,10))
# df.plot(kind='bar',figsize=(20,10))
# Bar Graph is used to compare rowwise
# Out:
# <AxesSubplot:>

# %%
# bar horizontal
df.iloc[5:11].plot.barh(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(figsize=(20,10))
# histogram x-axis will be the range
# histogram y-axis will be the count of that value
# similar to value_counts / groupby count in Pandas
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot.hist(figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# will perform histogram on each numerical columns seperately
df.hist(figsize=(20,10),color='#6A1B4D',alpha=0.9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="20d5562f-f49c-4948-9212-a8258736b569" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# histogram
df.iplot(kind='hist')
# Out:
# <div>                            <div id="bb82ea2f-1de1-4ffe-a57e-c74d5db062f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# scatter plot in cufflinks
df.iplot(x='sepal_length',y='sepal_width',kind='scatter',mode='markers',colors='#39BD00')
# Out:
# <div>                            <div id="40a6bb81-ae07-43c9-a906-279583cff0ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# bubble plot in cufflinks
# size is important for bubble
# df.iplot(x='sepal_length',y='sepal_width',kind='bubble',mode='markers',colors='#39BD00',size='sepal_length')
df.iplot(x='sepal_length',y='sepal_width',z='petal_length',kind='bubble3d',mode='markers',size='sepal_length',xTitle='x',yTitle='y',zTitle='z')
# Out:
# <div>                            <div id="5988077c-1ec6-4bc6-ab77-808a6df79b7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#  df1 = sns.load_dataset('tips')
df1 = pd.read_csv(r"C:\Users\udaya\Desktop\Python\DATA_SCIENCE\GRAPHS\Seaborn Dataset\tips.csv")

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# df1.iplot(kind='scatter',x='total_bill',y='tip',mode='markers')
df1.plot.scatter(x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(kind='scatter',x='total_bill',y='tip',mode='markers',colors="#9c34a3",xTitle='total_bill',yTitle='tip')
# Out:
# <div>                            <div id="acd6bd14-702c-465e-8807-b700eb375087" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# using seaborn
# hue is used for color that column category
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=df1,hue='smoker',style='sex')
# style is used to use icons
# hue is coloring based on category
# style and hue just performing grouping operation

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=df1,col='time')

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df,col='species')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=df1,col='day')

# %%
# categorical plot
sns.catplot(x='day',y='total_bill',data=df1)

# %%
# pairplot
sns.pairplot(data=df1)

# %%
sns.pairplot(data=df)

# %%
# using plotly we can able to plot similar to pairplot from seaborn
# only apply it to non-category column values
df.scatter_matrix()
# Out:
# <div>                            <div id="21cfb98d-29c1-42b7-912f-52568e008d14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# only apply it to non-category column values
df1[["total_bill","tip","size"]].scatter_matrix()
# Out:
# <div>                            <div id="64125146-b49a-40b0-bdef-2c1a639a0a7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# join plot - plot scatter and histogram plot combinely
sns.jointplot(x='total_bill',y='tip',data=df1)

# %%
sns.jointplot(x='total_bill',y='tip',data=df1,kind='hex')
# hexabin mark

# %%
# regression plot
sns.regplot(x='total_bill',y='tip',data=df1)
# set figure size with seaborn
sns.set(rc={'figure.figsize':(20,10)})

# %%
import plotly.express as px
px.scatter(df1,x='total_bill',y='tip',color='time')
# Out:
# <div>                            <div id="8acb347a-872e-44db-89ab-ea2df23aa012" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8acb347a-872e-44db-89ab-ea2df23aa012")) {                    Plotly.newPlot(                        "8acb347a-872e-44db-89ab-ea2df23aa012",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %%
px.bar(df1,x='sex',y='total_bill',color='smoker',barmode='group')
# Out:
# <div>                            <div id="02f844f9-f064-440e-b05d-568c0d099f41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02f844f9-f064-440e-b05d-568c0d099f41")) {                    Plotly.newPlot(                        "02f844f9-f064-440e-b05d-568c0d099f41",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...

# %%
px.scatter(
    df1, x='total_bill', y='tip', opacity=0.65,
    trendline='ols', trendline_color_override='darkblue'
)
# Out:
# <div>                            <div id="65deef17-bd94-4ffc-9a90-ed57e25661bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65deef17-bd94-4ffc-9a90-ed57e25661bc")) {                    Plotly.newPlot(                        "65deef17-bd94-4ffc-9a90-ed57e25661bc",                        [{"hovertemplate":"total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","opacity":0.65,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.46,13.94,9.
# ...
