# %%
import pandas as pd

# %%
df = pd.read_csv('DATASET/sales_data_final.csv')

# %%
df.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
#
# [2 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df['order_date']
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
type(df['order_date'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df[['profit','year']]
# Out:
#          profit  year
# 0      106.1400  2011
# 1       36.0360  2011
# 2       29.6400  2011
# 3      -26.0550  2011
# 4       37.7700  2011
# ...         ...   ...
# 51285    4.5188  2014
# 51286    0.4200  2014
# 51287   12.3600  2014
# 51288    0.5600  2014
# 51289   -0.6048  2014
#
# [51290 rows x 2 columns]

# %%
type(df[['profit','year']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['profit']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df[['order_id','product_id','quantity']]
# Out:
#               order_id        product_id  quantity
# 0         AG-2011-2040  OFF-TEN-10000025         2
# 1        IN-2011-47883   OFF-SU-10000618         3
# 2         HU-2011-1220  OFF-TEN-10001585         4
# 3      IT-2011-3647632   OFF-PA-10001492         3
# 4        IN-2011-47883   FUR-FU-10003447         5
# ...                ...               ...       ...
# 51285   CA-2014-115427   OFF-BI-10002103         2
# 51286     MO-2014-2560  OFF-WIL-10001069         1
# 51287   MX-2014-110527   OFF-LA-10004182         3
# 51288   MX-2014-114783   OFF-LA-10000413         1
# 51289   CA-2014-156720   OFF-FA-10003472         3
#
# [51290 rows x 3 columns]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
# statistics or analytics about the dataframe
df.describe()
# type(df.describe())
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes=='object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
# get list of all the column from the series
ls_col=df.dtypes[df.dtypes=='object'].index

# %%
# describe of object type only
df[ls_col].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
ls_col1=df.dtypes[df.dtypes=='float'].index

# %%
ls_col1
# Out:
# Index(['discount', 'profit', 'shipping_cost'], dtype='object')

# %%
df[ls_col1].head(3)
# Out:
#    discount   profit  shipping_cost
# 0       0.0  106.140          35.46
# 1       0.1   36.036           9.72
# 2       0.0   29.640           8.17

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id'][1:40:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
df.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
#
# [2 rows x 21 columns]

# %%
df['category1']="Test"
df.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ... sub_category  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
#
#                product_name sales quantity discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408        2      0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120        3      0.1   36.036           9.72
#
#    order_priority  year category1
# 0          Medium  2011      Test
# 1          Medium  2011      Test
#
# [2 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df['order_id'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: order_id, Length: 51290, dtype: bool

# %%
df[df['order_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year, category1]
# Index: []
#
# [0 rows x 22 columns]

# %%
df2=pd.read_excel(r"C:\Users\udaya\Desktop\Python\DATA_SCIENCE\PANDAS\DATASET\Dress Sales.xlsx")

# %%
df2
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df2.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00],
#       dtype='object')

# %%
df2['26/9/2013'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: 26/9/2013, Length: 500, dtype: bool

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
# filtering
df[df['profit']==df['profit'].max()]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df[df['country']=='Sweden'].head(3)
# Out:
#             order_id order_date  ship_date       ship_mode   customer_name  \
# 3    IT-2011-3647632   1/1/2011   1/5/2011    Second Class    Eugene Moren
# 168  IT-2011-5951216  1/13/2011  1/20/2011  Standard Class  Stuart Calhoun
# 477  IT-2011-5645183   2/3/2011   2/5/2011    Second Class      Max Ludwig
#
#          segment            state country market region  ... sub_category  \
# 3    Home Office        Stockholm  Sweden     EU  North  ...        Paper
# 168     Consumer  Vstra Gtaland  Sweden     EU  North  ...          Art
# 477  Home Office          Uppsala  Sweden     EU  North  ...          Art
#
#                             product_name sales quantity discount  profit  \
# 3            Enermax Note Cards, Premium    45        3      0.5 -26.055
# 168            Sanford Pens, Fluorescent    31        5      0.5 -13.650
# 477  Boston Pencil Sharpener, Easy-Erase    91        6      0.5 -61.650
#
#      shipping_cost  order_priority  year category1
# ...

# %%
df[df['country']=='Sweden']['order_id'].count()
# Out:
# 203

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# category1          object
# dtype: object

# %%
df[df['shipping_cost']>80]['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df[(df['shipping_cost']>100) & (df['profit']<10)].head(3)
# Out:
#             order_id order_date  ship_date       ship_mode customer_name  \
# 8      ID-2011-80230   1/3/2011   1/9/2011  Standard Class  Ken Lonsdale
# 257   MX-2011-146584  1/21/2011  1/27/2011  Standard Class  Hunter Lopez
# 451  ES-2011-1640672   2/2/2011   2/5/2011     First Class    Ken Heidel
#
#        segment     state      country market   region  ... sub_category  \
# 8     Consumer  Auckland  New Zealand   APAC  Oceania  ...      Copiers
# 257   Consumer   Managua    Nicaragua  LATAM  Central  ...       Tables
# 451  Corporate    Saxony      Germany     EU  Central  ...       Phones
#
#                                      product_name  sales quantity discount  \
# 8                     Hewlett Wireless Fax, Laser    912        4      0.4
# 257  Chromcraft Conference Table, Fully Assembled  2,797        6      0.2
# 451             Motorola Signal Booster, Cordless    584        8      0.5
#
#       profit  shipping_cost  order_priority  year category1
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
# learn
'2015' in df['ship_date']
# Out:
# False

# %%
df[['profit','customer_name']].max()
# Out:
# profit                     8399.976
# customer_name    Zuschuss Donatelli
# dtype: object

# %%
# date conversion
date = pd.to_datetime(df['order_date'])

# %%
type(date)
# Out:
# pandas.core.series.Series

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date']=date

# %%
df.head(2)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#                product_name sales quantity discount   profit  shipping_cost  \
# 0       Tenex Lockers, Blue   408        2      0.0  106.140          35.46
# 1  Acme Trimmer, High Speed   120        3      0.1   36.036           9.72
#
#    order_priority  year  category1 converted_order_date
# 0          Medium  2011       Test           2011-01-01
# 1          Medium  2011       Test           2011-01-01
#
# [2 rows x 23 columns]

# %%
# extract only the year
df['order_date_year']=df['converted_order_date'].dt.year

# %%
df['order_date_month']=df['converted_order_date'].dt.month

# %%
df.head(1)
# Out:
#        order_id order_date ship_date       ship_mode    customer_name  \
# 0  AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
#
#     segment        state  country  market  region  ... quantity discount  \
# 0  Consumer  Constantine  Algeria  Africa  Africa  ...        2      0.0
#
#    profit shipping_cost order_priority  year  category1  converted_order_date  \
# 0  106.14         35.46         Medium  2011       Test            2011-01-01
#
#    order_date_year order_date_month
# 0             2011                1
#
# [1 rows x 25 columns]

# %%
df['order_date_week']=df['converted_order_date'].dt.week
# Out:
# C:\Users\udaya\AppData\Local\Temp\ipykernel_11284\1937968909.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week']=df['converted_order_date'].dt.week

# %%
df.head(1)
# Out:
#        order_id order_date ship_date       ship_mode    customer_name  \
# 0  AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
#
#     segment        state  country  market  region  ... discount  profit  \
# 0  Consumer  Constantine  Algeria  Africa  Africa  ...      0.0  106.14
#
#   shipping_cost order_priority  year  category1  converted_order_date  \
# 0         35.46         Medium  2011       Test            2011-01-01
#
#    order_date_year  order_date_month order_date_week
# 0             2011                 1              52
#
# [1 rows x 26 columns]

# %%
df[['converted_order_date','order_date_week']]
# Out:
#       converted_order_date  order_date_week
# 0               2011-01-01               52
# 1               2011-01-01               52
# 2               2011-01-01               52
# 3               2011-01-01               52
# 4               2011-01-01               52
# ...                    ...              ...
# 51285           2014-12-31                1
# 51286           2014-12-31                1
# 51287           2014-12-31                1
# 51288           2014-12-31                1
# 51289           2014-12-31                1
#
# [51290 rows x 2 columns]

# %%
# grouping the columns
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'converted_order_date', 'order_date_year',
#        'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
df['cost to company'] = df['discount'] + df['shipping_cost']

# %%
df[df['cost to company'].max()==df['cost to company']]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
# delete columns
# axis 0 - delete row
# axis 1 - delete column
# to reflect in original df we need to use inplace
df.drop('category1',axis=1,inplace=True)

# %%
df.head(1)
# Out:
#        order_id order_date ship_date       ship_mode    customer_name  \
# 0  AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
#
#     segment        state  country  market  region  ... discount  profit  \
# 0  Consumer  Constantine  Algeria  Africa  Africa  ...      0.0  106.14
#
#   shipping_cost order_priority  year  converted_order_date  order_date_year  \
# 0         35.46         Medium  2011            2011-01-01             2011
#
#    order_date_month  order_date_week cost to company
# 0                 1               52           35.46
#
# [1 rows x 26 columns]

# %%
# delete rows
# df.drop(1,inplace=True)

# %%
df.head(1)
# Out:
#        order_id order_date ship_date       ship_mode    customer_name  \
# 0  AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
#
#     segment        state  country  market  region  ... discount  profit  \
# 0  Consumer  Constantine  Algeria  Africa  Africa  ...      0.0  106.14
#
#   shipping_cost order_priority  year  converted_order_date  order_date_year  \
# 0         35.46         Medium  2011            2011-01-01             2011
#
#    order_date_month  order_date_week cost to company
# 0                 1               52           35.46
#
# [1 rows x 26 columns]

# %%
# filer records based on rows
df[1:3]
# Out:
#         order_id order_date ship_date       ship_mode  customer_name  \
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class    Joseph Holt
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class  Annie Thurman
#
#     segment            state    country market   region  ... discount  profit  \
# 1  Consumer  New South Wales  Australia   APAC  Oceania  ...      0.1  36.036
# 2  Consumer         Budapest    Hungary   EMEA     EMEA  ...      0.0  29.640
#
#   shipping_cost order_priority  year  converted_order_date  order_date_year  \
# 1          9.72         Medium  2011            2011-01-01             2011
# 2          8.17           High  2011            2011-01-01             2011
#
#    order_date_month  order_date_week cost to company
# 1                 1               52            9.82
# 2                 1               52            8.17
#
# [2 rows x 26 columns]

# %%
df.loc[[2,3]]
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... discount  profit  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...      0.0  29.640
# 3  Home Office  Stockholm   Sweden     EU  North  ...      0.5 -26.055
#
#   shipping_cost order_priority  year  converted_order_date  order_date_year  \
# 2          8.17           High  2011            2011-01-01             2011
# 3          4.82           High  2011            2011-01-01             2011
#
#    order_date_month  order_date_week cost to company
# 2                 1               52            8.17
# 3                 1               52            5.32
#
# [2 rows x 26 columns]

# %%
# slicing row with step
df.loc[2:10:2]
# Out:
#          order_id order_date ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4   IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6    CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159   1/3/2011  1/7/2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#    discount    profit shipping_cost order_priority  year  \
# ...

# %%
# slicing row and column with loc
# for column slicing need to use col name in list if we are using loc
# loc - retrieved based on named Index
df.loc[0:4,['order_id','order_date','ship_date']]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 1    IN-2011-47883   1/1/2011  1/8/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
# iloc - default internal index based retrieval (it should not be always number, sometimes default index setup varies)
df.iloc[0:4,0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 1    IN-2011-47883   1/1/2011  1/8/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011

# %%
# with loc (named index)
df.loc[2:5,['ship_mode','customer_name','segment']]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
# with iloc (similar like list slicing reg upper bound)
df.iloc[2:6,3:6]
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
#
#        segment            state    country  market   region  ... discount  \
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 5     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 6     Consumer          Ontario     Canada  Canada   Canada  ...      0.0
#
#    profit shipping_cost order_priority  year  converted_order_date  \
# 3 -26.055          4.82           High  2011            2011-01-01
# 4  37.770          4.70         Medium  2011            2011-01-01
# ...

# %%
df2=df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index]

# %%
df2
# Out:
#        quantity  discount    profit  shipping_cost  year  order_date_year  \
# 0             2       0.0  106.1400          35.46  2011             2011
# 1             3       0.1   36.0360           9.72  2011             2011
# 2             4       0.0   29.6400           8.17  2011             2011
# 3             3       0.5  -26.0550           4.82  2011             2011
# 4             5       0.1   37.7700           4.70  2011             2011
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             2014
# 51286         1       0.0    0.4200           0.49  2014             2014
# 51287         3       0.0   12.3600           0.35  2014             2014
# 51288         1       0.0    0.5600           0.20  2014             2014
# 51289         3       0.2   -0.6048           0.17  2014             2014
#
#        order_date_month  order_date_week  cost to company
# ...

# %%
# perform the filter on the entire dataframe
df3 = df2[df2>100]

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 1           NaN       NaN     NaN            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week  cost to company
# ...

# %%
# drop na will drop row with atleast one NaN value with axis 0
df3.dropna()
# it removed all rows due to NaN was there in all rows
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, order_date_month, order_date_week, cost to company]
# Index: []

# %%
# drop na will drop column with atleast one NaN value with axis 1
df3.dropna(axis=1)
# Out:
#        year  order_date_year
# 0      2011             2011
# 1      2011             2011
# 2      2011             2011
# 3      2011             2011
# 4      2011             2011
# ...     ...              ...
# 51285  2014             2014
# 51286  2014             2014
# 51287  2014             2014
# 51288  2014             2014
# 51289  2014             2014
#
# [51290 rows x 2 columns]

# %%
# drop na based on the threshold
# thresh is minimum non NaN value presented t be not deleted
df3.dropna(thresh=3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        order_date_month  order_date_week  cost to company
# ...

# %%
# fill NaN with value provided in entire DF
df3.fillna(value=4)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           4.0       4.0  106.14            4.0  2011             2011
# 1           4.0       4.0    4.00            4.0  2011             2011
# 2           4.0       4.0    4.00            4.0  2011             2011
# 3           4.0       4.0    4.00            4.0  2011             2011
# 4           4.0       4.0    4.00            4.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014             2014
# 51286       4.0       4.0    4.00            4.0  2014             2014
# 51287       4.0       4.0    4.00            4.0  2014             2014
# 51288       4.0       4.0    4.00            4.0  2014             2014
# 51289       4.0       4.0    4.00            4.0  2014             2014
#
#        order_date_month  order_date_week  cost to company
# ...

# %%
df3.fillna(value=df3['profit'].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 1      285.710477  285.710477  285.710477     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        order_date_year  order_date_month  order_date_week  cost to company
# 0                 2011        285.710477       285.710477       285.710477
# ...

# %%
# group by operation in pandas
# average profit yearwise
df.groupby('order_date_year')['profit'].mean()
# Out:
# order_date_year
# 2011    27.666238
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
# average shipping cost yearwise
df.groupby('order_date_year')['shipping_cost'].mean()
# Out:
# order_date_year
# 2011    27.147264
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
# average discount yearwise
df.groupby('order_date_year')['discount'].mean()
# Out:
# order_date_year
# 2011    0.148188
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
# object to int conversion of column
# pd.to_numeric(df['sales'])

# %%
# replace , in column and converting it into integer
df['sales']=df.sales.str.replace(",","").astype(int)

# %%
# average sales yearwise
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.112581
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
# average quantity sold yearwise
df.groupby('order_date_year')['quantity'].mean()
# Out:
# order_date_year
# 2011    3.494443
# 2012    3.476647
# 2013    3.488369
# 2014    3.457989
# Name: quantity, dtype: float64

# %%
df.dtypes
# Out:
# order_id                        object
# order_date                      object
# ship_date                       object
# ship_mode                       object
# customer_name                   object
# segment                         object
# state                           object
# country                         object
# market                          object
# region                          object
# product_id                      object
# category                        object
# sub_category                    object
# product_name                    object
# sales                            int32
# quantity                         int64
# discount                       float64
# profit                         float64
# shipping_cost                  float64
# order_priority                  object
# year                             int64
# converted_order_date    datetime64[ns]
# order_date_year                  int64
# order_date_month                 int64
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'converted_order_date', 'order_date_year', 'order_date_month',
#        'order_date_week', 'cost to company'],
#       dtype='object')

# %%
df[['country','market']]
# Out:
#              country  market
# 0            Algeria  Africa
# 1          Australia    APAC
# 2            Hungary    EMEA
# 3             Sweden      EU
# 4          Australia    APAC
# ...              ...     ...
# 51285  United States      US
# 51286        Morocco  Africa
# 51287      Nicaragua   LATAM
# 51288         Mexico   LATAM
# 51289  United States      US
#
# [51290 rows x 2 columns]

# %%
# total quantity sold yearwise
df.groupby('order_date_year')['quantity'].sum()
# Out:
# order_date_year
# 2011    31443
# 2012    38111
# 2013    48136
# 2014    60622
# Name: quantity, dtype: int64

# %%
# total sales yearwise
df.groupby('order_date_year')['sales'].sum()
# Out:
# order_date_year
# 2011    2259511
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32

# %%
# Assignment

1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
2 .Total working days for each agents 
3. Total query that you have taken 
4. total Feedback that you have received 
5. a agent name who have average rating between 3.5 to 4 
6 . Agent name who have rating lesss then 3.5 
7 . agent name who have rating more then 4.5 
8 . how many feedaback agents have received more then 4.5 average
9 . average weekly response time for each agent 
10 . average weekely resolution time for each agents 
11 . list of all agents name 
12 . percentage of chat on which they have received a feedback 
13 . Total contributation hour for each and every agents weekly basis 
14. total percentage of active hour for a month

# %%
# 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

df_per = pd.read_csv(r"C:\Users\udaya\Desktop\Python\DATA_SCIENCE\PANDAS\DATASET\AgentPerformance.csv")

# %%
df_per.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1  7/30/2022   Prerna Singh           11              00:00:38
# 1      2  7/30/2022  Nandani Gupta           11              00:01:15
# 2      3  7/30/2022     Ameya Jain           14              00:00:30
# 3      4  7/30/2022  Mahesh Sarade           14              00:01:04
# 4      5  7/30/2022         Swati            14              00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                00:04:20            4.11               9
# 1                00:28:25            3.14               7
# 2                00:11:36            4.55              11
# 3                00:15:46            4.71               7
# 4                00:16:33            3.67               6

# %%
df_per.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df_per.groupby("Agent Name")["Average Rating"].mean()
# Out:
# Agent Name
# Abhishek         0.000000
# Aditya           0.000000
# Aditya Shinde    1.800333
# Aditya_iot       2.345333
# Amersh           0.000000
#                    ...
# Uday Mishra      0.000000
# Vasanth P        0.000000
# Vivek            0.500667
# Wasim            2.400000
# Zeeshan          2.287000
# Name: Average Rating, Length: 70, dtype: float64
